# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2
import pandas as pd
# %matplotlib inline

# %%
img_1_path = r"dataset/img1.jpg"
img_2_path = r"dataset/img2.jpg"

model_name = 'ArcFace'

response = DeepFace.verify(img1_path=img_1_path, img2_path=img_2_path, model_name=model_name)
# If model name isn't passed, VGG-Face is set as the default model
# Multiple stages of verification are taking place in the back-end of this verify() function

print(response)
# Out:
# ...
# 1/1 [==============================] - 0s 141ms/step
# {'verified': True, 'distance': 0.4939860962554834, 'threshold': 0.68, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}

# %%
img_1_path = r"dataset/img1.jpg"
img_2_path = r"dataset/img2.jpg"

model_name = 'VGG-Face'

response = DeepFace.verify(img1_path=img_1_path, img2_path=img_2_path, model_name=model_name)

print(response)
# Out:
# ...
# 1/1 [==============================] - 0s 259ms/step
# {'verified': True, 'distance': 0.25551898252856897, 'threshold': 0.4, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}

# %%
img_1_path = r"dataset/img1.jpg"
img_2_path = r"dataset/img2.jpg"

model_name = 'Facenet'

response = DeepFace.verify(img1_path=img_1_path, img2_path=img_2_path, model_name=model_name)

print(response)
# Out:
# ...
# 1/1 [==============================] - 0s 91ms/step
# {'verified': True, 'distance': 0.24256999142761537, 'threshold': 0.4, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}

# %%
img1 = DeepFace.detectFace(img_1_path)
img2 = DeepFace.detectFace(img_2_path)

# %%
img1_bgr = cv2.imread(img_1_path)
img1_rgb = cv2.cvtColor(img1_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img1_rgb) #original image

# %%
plt.imshow(img1) # Detected and Aligned versions of the image

# %%
img2_bgr = cv2.imread(img_2_path)
img2_rgb = cv2.cvtColor(img2_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img2_rgb) #original image

# %%
plt.imshow(img2)

# %%
# find() method:
df = DeepFace.find(img_path = 'source.png', db_path = 'dataset/')
# this is another image of angelina jolie outside the dataset directory, we'll try to find matching images in the dataset
# Out:
# WARNING: Representations for images in  dataset/  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  61  representations found in  representations_vgg_face.pkl
# 1/1 [==============================] - 0s 239ms/step
# find function lasts  1.017228126525879  seconds

# %%
df.head() # will show all matching images
# Out:
#              identity  VGG-Face_cosine
# 0  dataset//img10.jpg         0.149642
# 1   dataset//img2.jpg         0.160322
# 2   dataset//img4.jpg         0.167676
# 3   dataset//img6.jpg         0.188352
# 4  dataset//img11.jpg         0.201619

# %%
obj = DeepFace.analyze(img_path = img_1_path)
obj
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:05<00:00,  1.35s/it]
# {'emotion': {'angry': 8.507665280999591e-22,
#   'disgust': 0.0,
#   'fear': 1.7665076325852136e-27,
#   'happy': 100.0,
#   'sad': 3.718021757061006e-18,
#   'surprise': 7.54283094317465e-09,
#   'neutral': 2.3138044813464376e-07},
#  'dominant_emotion': 'happy',
#  'region': {'x': 345, 'y': 211, 'w': 769, 'h': 769},
#  'age': 31,
#  'gender': 'Woman',
#  'race': {'asian': 9.939994663000107,
#   'indian': 13.22726309299469,
#   'black': 3.6370791494846344,
#   'white': 23.46402108669281,
#   'middle eastern': 20.388375222682953,
#   'latino hispanic': 29.343268275260925},
#  'dominant_race': 'latino hispanic'}
